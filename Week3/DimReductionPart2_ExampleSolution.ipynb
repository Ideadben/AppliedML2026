# %% [markdown]
# # Dimensionality reduction 2
#
# __Week 2 - 4 May 2022__
#
# After we have practised using some dimensionality reduction algorithms in basic mode, we will now turn our attention to arguably the most important part of the process - preprocessing and hyperparameter optimisation. Hopefully this will show how these steps can be crucial in producing the best possible representation of data in lower dimensions. Here, we will make use of a new astronomical dataset with the same algorithms as before (`PCA`, `t-SNE`, `UMAP`). We will end by returning to galaxies in COSMOS2015 and improving on the results from the previous session.
#
# For a good overview of how `t-SNE` and `UMAP` work and compare, please see:\
# https://towardsdatascience.com/how-exactly-umap-works-13e3040e1668?gi=3ddf4de3641f.
#
# ---
# ### Data
#
# Swift dataset - the dataset is light curves (intensity of light on a timeline) of gamma-ray bursts (GRB) coming from the far reaches of the universe. However, here we give the time-series of the bursts (signal as a function of time). In addition to the raw data, there are several derived properties (related to either time of the bursts or their intensity and wavelength):
#
# * `T90_start` & `T90_end` - start and end times of the bursts of light.
# * `fluence`
# * `hardness`
#
# ---
# ### Exercise
#
# You have now practiced reducing a dataset to a set of basis vectors via some projection or higher-dimenion embedding. The next step is to take an additional step of considering which data it is best to use in the first place and how to prepare it.
#
# * Apply your favourite dimensionality reduction algorithm to: (1) properties, (2) raw observed data, (3) preprocessed observed data in the Swift dataset.
#
# * Tweak hyperparameters of the algorithm - can you find an optimal combination?
#
# * P.S. Why use only one of the algorithms at a time? Think about using one of these for preprocessing and the other for dimensionality reduction (eg., `PCA` + `t-SNE`).
#
#
# ---
# * Authors:  Vadim Rusakov, Charles Steinhardt, Jackson Mann
# * Email:  vadim.rusakov@nbi.ku.dk
# * Date:   27th of April 2022

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import umap
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA, KernelPCA

# %% [markdown]
# Load the raw data (light curves), as well as the properties (derived form raw data).
#
# Make sure to get rid of the `NaN` entries.

# %%
# loading data (light curves)
data = pd.read_pickle('datasets/swift_gamma_ray_bursts.zip')
    
# loading derived properties
props_full = pd.read_csv('datasets/SwiftProperties.csv')

# match & merge properties and raw data tables
df_merged = pd.merge(props_full, data, left_on='GRBname', right_index=True, how='inner')
mask = ~np.isnan(df_merged.iloc[:, 1:]).any(axis=1) # mask of NaNs
df_clean = df_merged.loc[mask] # clean of NaNs
X_data = df_merged.values[mask, 7:] # raw data
X_props = df_merged.values[mask, :7] # derived properties

print(f"the shape of the raw data set (nsamples, nfeatures): {X_data.shape}")
print(f"the shape of the properties data set (nsamples, nfeatures): {X_props.shape}")
# Out:
# the shape of the raw data set (nsamples, nfeatures): (1313, 51764)
# the shape of the properties data set (nsamples, nfeatures): (1313, 7)

# %% [markdown]
# ## Dataset 1. Gamma-ray bursts
#
# 1. Run your favourite algorithm (`t-SNE` or `UMAP`) on the bursts properties (`X_props`). Does it manage to split the samples into two types: eg., short and long bursts? $^1$
#
# 2. Can you explain the clumpiness of the reduction? Based on this, do derived prperties give a meaningful reduction? In not, can you argue why?
#
#
# $^1$ Hint: short- or long-type of bursts separation is not obvious. Calculate the duration of bursts using the properties table and by subtracting `T90_start` from `T90_end`. Colour your scatter plots in reduced dimensions by duration. Try other properties as well.

# %%
# running t-SNE
tsne = TSNE(perplexity=15, max_iter=1500, init='random', verbose=2, 
            learning_rate='auto', method='barnes_hut', random_state=42)
y = tsne.fit_transform(X_props[:, 1:])
# Out:
# [t-SNE] Computing 46 nearest neighbors...
# [t-SNE] Indexed 1313 samples in 0.002s...
# [t-SNE] Computed neighbors for 1313 samples in 0.013s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1313
# [t-SNE] Computed conditional probabilities for sample 1313 / 1313
# [t-SNE] Mean sigma: 0.921366
# [t-SNE] Computed conditional probabilities in 0.016s
# [t-SNE] Iteration 50: error = 76.1732559, gradient norm = 0.1115403 (50 iterations in 0.182s)
# [t-SNE] Iteration 100: error = 63.4776230, gradient norm = 0.0199434 (50 iterations in 0.144s)
# [t-SNE] Iteration 150: error = 61.2751350, gradient norm = 0.0118554 (50 iterations in 0.143s)
# [t-SNE] Iteration 200: error = 60.2868729, gradient norm = 0.0113381 (50 iterations in 0.136s)
# [t-SNE] Iteration 250: error = 59.7692947, gradient norm = 0.0100119 (50 iterations in 0.136s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 59.769295
# [t-SNE] Iteration 300: error = 1.1502901, gradient norm = 0.0229192 (50 iterations in 0.128s)
# [t-SNE] Iteration 350: error = 0.7928193, gradient norm = 0.0172174 (50 iterations in 0.200s)
# [t-SNE] Iteration 400: error = 0.6666393, gradient norm = 0.0141638 (50 iterations in 0.146s)
# [t-SNE] Iteration 450: error = 0.6058890, gradient norm = 0.0121290 (50 iterations in 0.132s)
# [t-SNE] Iteration 500: error = 0.5717998, gradient norm = 0.0100260 (50 iterations in 0.132s)
# [t-SNE] Iteration 550: error = 0.5524173, gradient norm = 0.0077553 (50 iterations in 0.131s)
# [t-SNE] Iteration 600: error = 0.5409265, gradient norm = 0.0059631 (50 iterations in 0.131s)
# [t-SNE] Iteration 650: error = 0.5337178, gradient norm = 0.0042763 (50 iterations in 0.135s)
# [t-SNE] Iteration 700: error = 0.5288590, gradient norm = 0.0036766 (50 iterations in 0.135s)
# [t-SNE] Iteration 750: error = 0.5248855, gradient norm = 0.0029214 (50 iterations in 0.130s)
# [t-SNE] Iteration 800: error = 0.5217407, gradient norm = 0.0027815 (50 iterations in 0.130s)
# [t-SNE] Iteration 850: error = 0.5192242, gradient norm = 0.0023087 (50 iterations in 0.130s)
# [t-SNE] Iteration 900: error = 0.5168628, gradient norm = 0.0024844 (50 iterations in 0.131s)
# [t-SNE] Iteration 950: error = 0.5147693, gradient norm = 0.0022949 (50 iterations in 0.130s)
# [t-SNE] Iteration 1000: error = 0.5130337, gradient norm = 0.0020836 (50 iterations in 0.135s)
# [t-SNE] Iteration 1050: error = 0.5115002, gradient norm = 0.0019690 (50 iterations in 0.133s)
# [t-SNE] Iteration 1100: error = 0.5099746, gradient norm = 0.0020784 (50 iterations in 0.134s)
# [t-SNE] Iteration 1150: error = 0.5087910, gradient norm = 0.0018211 (50 iterations in 0.133s)
# [t-SNE] Iteration 1200: error = 0.5077798, gradient norm = 0.0018637 (50 iterations in 0.130s)
# [t-SNE] Iteration 1250: error = 0.5066266, gradient norm = 0.0016976 (50 iterations in 0.132s)
# [t-SNE] Iteration 1300: error = 0.5054402, gradient norm = 0.0016280 (50 iterations in 0.143s)
# [t-SNE] Iteration 1350: error = 0.5046825, gradient norm = 0.0012356 (50 iterations in 0.130s)
# [t-SNE] Iteration 1400: error = 0.5040698, gradient norm = 0.0011416 (50 iterations in 0.133s)
# [t-SNE] Iteration 1450: error = 0.5033703, gradient norm = 0.0010661 (50 iterations in 0.139s)
# [t-SNE] Iteration 1500: error = 0.5028099, gradient norm = 0.0010557 (50 iterations in 0.144s)
# [t-SNE] KL divergence after 1500 iterations: 0.502810

# %%
fig, ax = plt.subplots(1, figsize=(6, 5), dpi=100)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')

duration = np.log10(df_clean['T90_end'] - df_clean['T90_start'])

sc = ax.scatter(y[:, 0], y[:, 1], s=2.0, c=duration, cmap='jet')
cbar = plt.colorbar(sc)
cbar.ax.set_ylabel('Duration', rotation=270, labelpad=10)
plt.show()

# %% [markdown]
# Reapeat with `UMAP`:

# %%
map = umap.UMAP(n_components=2, n_neighbors=50, random_state=42)
y = map.fit_transform(X_props[:, 1:])
# Out:
# /home/marc/miniconda3/envs/appmlenv/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
fig, ax = plt.subplots(1, figsize=(6, 5), dpi=100)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')

sc = ax.scatter(y[:, 0], y[:, 1], s=1.0, c=duration,  cmap='jet')
cbar = plt.colorbar(sc)
cbar.ax.set_ylabel('Duration', rotation=270, labelpad=10)
plt.show()

# %% [markdown]
# As we can see from above, the two-dimensional maps look meaningful, when coloured by their properties (eg., you can see a gradient in terms of some of these properties).
#
# Also, we don't get separate classes of objects, but rather a continuum. We don't have labels for these data, which means that there may well not be any classes, but before we can conclude that, we can still do a certian amount of data preparation.
#
# Finally, observe the clumpiness above and compare this with the map you will see below - how do they compare?

# %% [markdown]
# 3. Now train the algorithm with the raw data `X_data`. Are you able to make cleaner classifications using the projections in the space learnt by the algorithms? If not, do you have some ideas for how to improve this?

# %%
map = umap.UMAP(n_components=2, n_neighbors=50, random_state=42)
y = map.fit_transform(X_data)

# %%
fig, ax = plt.subplots(1, figsize=(6, 5), dpi=100)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
duration = np.log10(df_clean['T90_end'] - df_clean['T90_start'])

sc = ax.scatter(y[:, 0], y[:, 1], s=2.0, c=duration, cmap='jet')
cbar = plt.colorbar(sc)
cbar.ax.set_ylabel('Duration', rotation=270, labelpad=10)
plt.show()

# %% [markdown]
# The map obtained above using the raw data is certianly less clumpier than the one obtained using the derived properties before. As if the objects in the new 2D-space have more freedom when described in terms of the raw data.
#
# This makes sense, because the properties are some sort of linear/non-linear combination of the raw data. In addition, it is always the possible that in the process of deriving the properties some data may be discarded. It means that the properties may carry less information than the raw data, or, in the best case, as mush as the raw data. Therefore it is always best to start with the raw data in dimension reduction.

# %% [markdown]
# 4. Suggestion: try converting the time-series `X_data` to frequency space by taking a Fourier transform. Repeat the exercise. Does this help to create a cleaner representation in the reduced space? What physical meaning does the separation imply? (for eg., in terms of the burst duration property).
#
# **Note**: application of the Fourier transform is not intuituve here and specific of the data at hand. It does not mean that you should use this as a standard go-to approach in any case. Here we have time-series data (signal as a function of time), where the signal was recorded with a telescope. The starting times of the recordings of different events were not always aligned. Therefore the Fourier transform is helpful here to use the frequency information about the signals, rather than the biased time-series.

# %%
# taking Fast Fourier Transform
X_data_float = X_data.astype(float) # Convert to format compatible with fft
X_data_fft = abs(np.fft.rfft(X_data_float)) # take modulus to convert to float from complex data type
mask_fft = ~np.isnan(X_data_fft[:, 1:]).any(axis=1) # NaNs
X_data_mod = X_data_fft[mask_fft] # mask out NaNs

# %%
# running t-SNE
tsne = TSNE(perplexity=15, max_iter=15000, init='random', verbose=2, 
            learning_rate='auto', method='barnes_hut', random_state=42)
y_tsne = tsne.fit_transform(X_data_mod)
# Out:
# [t-SNE] Computing 46 nearest neighbors...
# [t-SNE] Indexed 1313 samples in 0.024s...
# [t-SNE] Computed neighbors for 1313 samples in 0.973s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1313
# [t-SNE] Computed conditional probabilities for sample 1313 / 1313
# [t-SNE] Mean sigma: 10993906.026536
# [t-SNE] Computed conditional probabilities in 0.046s
# [t-SNE] Iteration 50: error = 76.6130142, gradient norm = 0.0294209 (50 iterations in 0.205s)
# [t-SNE] Iteration 100: error = 69.8990631, gradient norm = 0.0117040 (50 iterations in 0.175s)
# [t-SNE] Iteration 150: error = 69.2874603, gradient norm = 0.0009218 (50 iterations in 0.175s)
# [t-SNE] Iteration 200: error = 69.2761917, gradient norm = 0.0003978 (50 iterations in 0.159s)
# [t-SNE] Iteration 250: error = 69.2758484, gradient norm = 0.0003001 (50 iterations in 0.165s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.275848
# [t-SNE] Iteration 300: error = 1.6274570, gradient norm = 0.0158173 (50 iterations in 0.150s)
# [t-SNE] Iteration 350: error = 1.4515653, gradient norm = 0.0120324 (50 iterations in 0.157s)
# [t-SNE] Iteration 400: error = 1.3862970, gradient norm = 0.0096612 (50 iterations in 0.146s)
# [t-SNE] Iteration 450: error = 1.3546295, gradient norm = 0.0079001 (50 iterations in 0.154s)
# [t-SNE] Iteration 500: error = 1.3381267, gradient norm = 0.0062691 (50 iterations in 0.142s)
# [t-SNE] Iteration 550: error = 1.3284048, gradient norm = 0.0048592 (50 iterations in 0.146s)
# [t-SNE] Iteration 600: error = 1.3231157, gradient norm = 0.0031413 (50 iterations in 0.139s)
# [t-SNE] Iteration 650: error = 1.3196032, gradient norm = 0.0024939 (50 iterations in 0.150s)
# [t-SNE] Iteration 700: error = 1.3170022, gradient norm = 0.0022566 (50 iterations in 0.148s)
# [t-SNE] Iteration 750: error = 1.3152217, gradient norm = 0.0018912 (50 iterations in 0.151s)
# [t-SNE] Iteration 800: error = 1.3136748, gradient norm = 0.0014720 (50 iterations in 0.143s)
# [t-SNE] Iteration 850: error = 1.3122386, gradient norm = 0.0015498 (50 iterations in 0.157s)
# [t-SNE] Iteration 900: error = 1.3111324, gradient norm = 0.0012974 (50 iterations in 0.142s)
# [t-SNE] Iteration 950: error = 1.3102593, gradient norm = 0.0011361 (50 iterations in 0.149s)
# [t-SNE] Iteration 1000: error = 1.3093891, gradient norm = 0.0011111 (50 iterations in 0.146s)
# [t-SNE] Iteration 1050: error = 1.3088067, gradient norm = 0.0009851 (50 iterations in 0.162s)
# [t-SNE] Iteration 1100: error = 1.3080997, gradient norm = 0.0010059 (50 iterations in 0.147s)
# [t-SNE] Iteration 1150: error = 1.3074887, gradient norm = 0.0009168 (50 iterations in 0.152s)
# [t-SNE] Iteration 1200: error = 1.3068056, gradient norm = 0.0011543 (50 iterations in 0.147s)
# [t-SNE] Iteration 1250: error = 1.3062475, gradient norm = 0.0008497 (50 iterations in 0.142s)
# [t-SNE] Iteration 1300: error = 1.3056735, gradient norm = 0.0009171 (50 iterations in 0.142s)
# [t-SNE] Iteration 1350: error = 1.3054056, gradient norm = 0.0006303 (50 iterations in 0.154s)
# [t-SNE] Iteration 1400: error = 1.3049927, gradient norm = 0.0007826 (50 iterations in 0.146s)
# [t-SNE] Iteration 1450: error = 1.3046424, gradient norm = 0.0007544 (50 iterations in 0.145s)
# [t-SNE] Iteration 1500: error = 1.3041537, gradient norm = 0.0008455 (50 iterations in 0.141s)
# [t-SNE] Iteration 1550: error = 1.3038117, gradient norm = 0.0006921 (50 iterations in 0.148s)
# [t-SNE] Iteration 1600: error = 1.3034178, gradient norm = 0.0007556 (50 iterations in 0.139s)
# [t-SNE] Iteration 1650: error = 1.3030090, gradient norm = 0.0006218 (50 iterations in 0.158s)
# [t-SNE] Iteration 1700: error = 1.3027761, gradient norm = 0.0007753 (50 iterations in 0.150s)
# [t-SNE] Iteration 1750: error = 1.3025243, gradient norm = 0.0007015 (50 iterations in 0.149s)
# [t-SNE] Iteration 1800: error = 1.3023103, gradient norm = 0.0006333 (50 iterations in 0.145s)
# [t-SNE] Iteration 1850: error = 1.3020802, gradient norm = 0.0006091 (50 iterations in 0.153s)
# [t-SNE] Iteration 1900: error = 1.3018377, gradient norm = 0.0004618 (50 iterations in 0.140s)
# [t-SNE] Iteration 1950: error = 1.3016138, gradient norm = 0.0005118 (50 iterations in 0.148s)
# [t-SNE] Iteration 2000: error = 1.3014451, gradient norm = 0.0006775 (50 iterations in 0.144s)
# [t-SNE] Iteration 2050: error = 1.3012637, gradient norm = 0.0006138 (50 iterations in 0.147s)
# [t-SNE] Iteration 2100: error = 1.3011338, gradient norm = 0.0004549 (50 iterations in 0.151s)
# [t-SNE] Iteration 2150: error = 1.3009706, gradient norm = 0.0003717 (50 iterations in 0.154s)
# [t-SNE] Iteration 2200: error = 1.3008598, gradient norm = 0.0003924 (50 iterations in 0.144s)
# [t-SNE] Iteration 2250: error = 1.3007081, gradient norm = 0.0004519 (50 iterations in 0.151s)
# [t-SNE] Iteration 2300: error = 1.3005699, gradient norm = 0.0003469 (50 iterations in 0.146s)
# [t-SNE] Iteration 2350: error = 1.3005104, gradient norm = 0.0003746 (50 iterations in 0.150s)
# [t-SNE] Iteration 2400: error = 1.3003097, gradient norm = 0.0003698 (50 iterations in 0.155s)
# [t-SNE] Iteration 2450: error = 1.3002337, gradient norm = 0.0003400 (50 iterations in 0.146s)
# [t-SNE] Iteration 2500: error = 1.3001022, gradient norm = 0.0003484 (50 iterations in 0.148s)
# [t-SNE] Iteration 2550: error = 1.2999861, gradient norm = 0.0003937 (50 iterations in 0.146s)
# [t-SNE] Iteration 2600: error = 1.2999443, gradient norm = 0.0003140 (50 iterations in 0.150s)
# [t-SNE] Iteration 2650: error = 1.2998703, gradient norm = 0.0004880 (50 iterations in 0.152s)
# [t-SNE] Iteration 2700: error = 1.2997268, gradient norm = 0.0003417 (50 iterations in 0.145s)
# [t-SNE] Iteration 2750: error = 1.2996457, gradient norm = 0.0006045 (50 iterations in 0.152s)
# [t-SNE] Iteration 2800: error = 1.2995110, gradient norm = 0.0003219 (50 iterations in 0.147s)
# [t-SNE] Iteration 2850: error = 1.2994212, gradient norm = 0.0002641 (50 iterations in 0.151s)
# [t-SNE] Iteration 2900: error = 1.2993492, gradient norm = 0.0002653 (50 iterations in 0.144s)
# [t-SNE] Iteration 2950: error = 1.2992775, gradient norm = 0.0002799 (50 iterations in 0.149s)
# [t-SNE] Iteration 3000: error = 1.2992189, gradient norm = 0.0002854 (50 iterations in 0.153s)
# [t-SNE] Iteration 3050: error = 1.2991261, gradient norm = 0.0003988 (50 iterations in 0.148s)
# [t-SNE] Iteration 3100: error = 1.2990599, gradient norm = 0.0002856 (50 iterations in 0.149s)
# [t-SNE] Iteration 3150: error = 1.2990570, gradient norm = 0.0002370 (50 iterations in 0.152s)
# [t-SNE] Iteration 3200: error = 1.2989264, gradient norm = 0.0002536 (50 iterations in 0.145s)
# [t-SNE] Iteration 3250: error = 1.2988492, gradient norm = 0.0003173 (50 iterations in 0.149s)
# [t-SNE] Iteration 3300: error = 1.2986879, gradient norm = 0.0005299 (50 iterations in 0.143s)
# [t-SNE] Iteration 3350: error = 1.2985959, gradient norm = 0.0003248 (50 iterations in 0.155s)
# [t-SNE] Iteration 3400: error = 1.2986180, gradient norm = 0.0002412 (50 iterations in 0.144s)
# [t-SNE] Iteration 3450: error = 1.2985902, gradient norm = 0.0004223 (50 iterations in 0.152s)
# [t-SNE] Iteration 3500: error = 1.2985128, gradient norm = 0.0002976 (50 iterations in 0.148s)
# [t-SNE] Iteration 3550: error = 1.2984638, gradient norm = 0.0002938 (50 iterations in 0.149s)
# [t-SNE] Iteration 3600: error = 1.2984431, gradient norm = 0.0003506 (50 iterations in 0.142s)
# [t-SNE] Iteration 3650: error = 1.2983463, gradient norm = 0.0003595 (50 iterations in 0.159s)
# [t-SNE] Iteration 3700: error = 1.2982634, gradient norm = 0.0002158 (50 iterations in 0.146s)
# [t-SNE] Iteration 3750: error = 1.2982156, gradient norm = 0.0002705 (50 iterations in 0.159s)
# [t-SNE] Iteration 3800: error = 1.2981424, gradient norm = 0.0002409 (50 iterations in 0.147s)
# [t-SNE] Iteration 3850: error = 1.2981663, gradient norm = 0.0002743 (50 iterations in 0.154s)
# [t-SNE] Iteration 3900: error = 1.2981498, gradient norm = 0.0002913 (50 iterations in 0.141s)
# [t-SNE] Iteration 3950: error = 1.2980283, gradient norm = 0.0002279 (50 iterations in 0.147s)
# [t-SNE] Iteration 4000: error = 1.2979209, gradient norm = 0.0002220 (50 iterations in 0.156s)
# [t-SNE] Iteration 4050: error = 1.2979224, gradient norm = 0.0002742 (50 iterations in 0.154s)
# [t-SNE] Iteration 4100: error = 1.2978560, gradient norm = 0.0003375 (50 iterations in 0.141s)
# [t-SNE] Iteration 4150: error = 1.2978033, gradient norm = 0.0002669 (50 iterations in 0.151s)
# [t-SNE] Iteration 4200: error = 1.2977617, gradient norm = 0.0003523 (50 iterations in 0.137s)
# [t-SNE] Iteration 4250: error = 1.2977140, gradient norm = 0.0002874 (50 iterations in 0.143s)
# [t-SNE] Iteration 4300: error = 1.2975445, gradient norm = 0.0004830 (50 iterations in 0.145s)
# [t-SNE] Iteration 4350: error = 1.2975793, gradient norm = 0.0002618 (50 iterations in 0.142s)
# [t-SNE] Iteration 4400: error = 1.2975178, gradient norm = 0.0003047 (50 iterations in 0.141s)
# [t-SNE] Iteration 4450: error = 1.2974581, gradient norm = 0.0002973 (50 iterations in 0.147s)
# [t-SNE] Iteration 4500: error = 1.2973373, gradient norm = 0.0002610 (50 iterations in 0.154s)
# [t-SNE] Iteration 4550: error = 1.2973388, gradient norm = 0.0002590 (50 iterations in 0.156s)
# [t-SNE] Iteration 4600: error = 1.2972597, gradient norm = 0.0002078 (50 iterations in 0.143s)
# [t-SNE] Iteration 4650: error = 1.2972976, gradient norm = 0.0003203 (50 iterations in 0.143s)
# [t-SNE] Iteration 4700: error = 1.2972847, gradient norm = 0.0002391 (50 iterations in 0.146s)
# [t-SNE] Iteration 4750: error = 1.2972437, gradient norm = 0.0002412 (50 iterations in 0.147s)
# [t-SNE] Iteration 4800: error = 1.2971866, gradient norm = 0.0002253 (50 iterations in 0.146s)
# [t-SNE] Iteration 4850: error = 1.2971432, gradient norm = 0.0001944 (50 iterations in 0.150s)
# [t-SNE] Iteration 4900: error = 1.2970684, gradient norm = 0.0002530 (50 iterations in 0.146s)
# [t-SNE] Iteration 4950: error = 1.2970579, gradient norm = 0.0002049 (50 iterations in 0.149s)
# [t-SNE] Iteration 5000: error = 1.2970266, gradient norm = 0.0002358 (50 iterations in 0.142s)
# [t-SNE] Iteration 5050: error = 1.2970078, gradient norm = 0.0003132 (50 iterations in 0.154s)
# [t-SNE] Iteration 5100: error = 1.2970129, gradient norm = 0.0001916 (50 iterations in 0.155s)
# [t-SNE] Iteration 5150: error = 1.2969781, gradient norm = 0.0001625 (50 iterations in 0.152s)
# [t-SNE] Iteration 5200: error = 1.2969223, gradient norm = 0.0002430 (50 iterations in 0.143s)
# [t-SNE] Iteration 5250: error = 1.2969404, gradient norm = 0.0001827 (50 iterations in 0.146s)
# [t-SNE] Iteration 5300: error = 1.2968750, gradient norm = 0.0002106 (50 iterations in 0.135s)
# [t-SNE] Iteration 5350: error = 1.2969346, gradient norm = 0.0001945 (50 iterations in 0.148s)
# [t-SNE] Iteration 5400: error = 1.2968795, gradient norm = 0.0001916 (50 iterations in 0.143s)
# [t-SNE] Iteration 5450: error = 1.2969022, gradient norm = 0.0001426 (50 iterations in 0.154s)
# [t-SNE] Iteration 5500: error = 1.2967498, gradient norm = 0.0002201 (50 iterations in 0.143s)
# [t-SNE] Iteration 5550: error = 1.2967052, gradient norm = 0.0002262 (50 iterations in 0.150s)
# [t-SNE] Iteration 5600: error = 1.2966983, gradient norm = 0.0001556 (50 iterations in 0.142s)
# [t-SNE] Iteration 5650: error = 1.2966384, gradient norm = 0.0003120 (50 iterations in 0.167s)
# [t-SNE] Iteration 5700: error = 1.2966695, gradient norm = 0.0002069 (50 iterations in 0.164s)
# [t-SNE] Iteration 5750: error = 1.2966187, gradient norm = 0.0002281 (50 iterations in 0.148s)
# [t-SNE] Iteration 5800: error = 1.2965981, gradient norm = 0.0001488 (50 iterations in 0.152s)
# [t-SNE] Iteration 5850: error = 1.2966000, gradient norm = 0.0002140 (50 iterations in 0.150s)
# [t-SNE] Iteration 5900: error = 1.2965407, gradient norm = 0.0001566 (50 iterations in 0.143s)
# [t-SNE] Iteration 5950: error = 1.2965744, gradient norm = 0.0001344 (50 iterations in 0.147s)
# [t-SNE] Iteration 6000: error = 1.2965569, gradient norm = 0.0001378 (50 iterations in 0.139s)
# [t-SNE] Iteration 6050: error = 1.2965701, gradient norm = 0.0001919 (50 iterations in 0.148s)
# [t-SNE] Iteration 6100: error = 1.2965034, gradient norm = 0.0002805 (50 iterations in 0.146s)
# [t-SNE] Iteration 6150: error = 1.2965226, gradient norm = 0.0002015 (50 iterations in 0.149s)
# [t-SNE] Iteration 6200: error = 1.2964762, gradient norm = 0.0001917 (50 iterations in 0.147s)
# [t-SNE] Iteration 6250: error = 1.2964592, gradient norm = 0.0001900 (50 iterations in 0.151s)
# [t-SNE] Iteration 6300: error = 1.2964704, gradient norm = 0.0001546 (50 iterations in 0.142s)
# [t-SNE] Iteration 6350: error = 1.2964756, gradient norm = 0.0002384 (50 iterations in 0.146s)
# [t-SNE] Iteration 6400: error = 1.2964056, gradient norm = 0.0001090 (50 iterations in 0.147s)
# [t-SNE] Iteration 6450: error = 1.2964290, gradient norm = 0.0001641 (50 iterations in 0.148s)
# [t-SNE] Iteration 6500: error = 1.2964046, gradient norm = 0.0002059 (50 iterations in 0.151s)
# [t-SNE] Iteration 6550: error = 1.2963750, gradient norm = 0.0002407 (50 iterations in 0.149s)
# [t-SNE] Iteration 6600: error = 1.2964140, gradient norm = 0.0002287 (50 iterations in 0.148s)
# [t-SNE] Iteration 6650: error = 1.2963707, gradient norm = 0.0001634 (50 iterations in 0.150s)
# [t-SNE] Iteration 6700: error = 1.2963028, gradient norm = 0.0001555 (50 iterations in 0.156s)
# [t-SNE] Iteration 6750: error = 1.2963243, gradient norm = 0.0002193 (50 iterations in 0.156s)
# [t-SNE] Iteration 6800: error = 1.2962919, gradient norm = 0.0001731 (50 iterations in 0.157s)
# [t-SNE] Iteration 6850: error = 1.2962599, gradient norm = 0.0001708 (50 iterations in 0.158s)
# [t-SNE] Iteration 6900: error = 1.2962701, gradient norm = 0.0001926 (50 iterations in 0.150s)
# [t-SNE] Iteration 6950: error = 1.2962089, gradient norm = 0.0002117 (50 iterations in 0.147s)
# [t-SNE] Iteration 7000: error = 1.2962188, gradient norm = 0.0001378 (50 iterations in 0.142s)
# [t-SNE] Iteration 7050: error = 1.2961423, gradient norm = 0.0003231 (50 iterations in 0.146s)
# [t-SNE] Iteration 7100: error = 1.2962067, gradient norm = 0.0002267 (50 iterations in 0.148s)
# [t-SNE] Iteration 7150: error = 1.2962039, gradient norm = 0.0002221 (50 iterations in 0.145s)
# [t-SNE] Iteration 7200: error = 1.2961566, gradient norm = 0.0001840 (50 iterations in 0.148s)
# [t-SNE] Iteration 7250: error = 1.2961704, gradient norm = 0.0002427 (50 iterations in 0.147s)
# [t-SNE] Iteration 7300: error = 1.2961618, gradient norm = 0.0002016 (50 iterations in 0.144s)
# [t-SNE] Iteration 7350: error = 1.2960610, gradient norm = 0.0001573 (50 iterations in 0.149s)
# [t-SNE] Iteration 7400: error = 1.2960745, gradient norm = 0.0002440 (50 iterations in 0.146s)
# [t-SNE] Iteration 7450: error = 1.2960451, gradient norm = 0.0001381 (50 iterations in 0.146s)
# [t-SNE] Iteration 7500: error = 1.2960515, gradient norm = 0.0002123 (50 iterations in 0.149s)
# [t-SNE] Iteration 7550: error = 1.2960351, gradient norm = 0.0002343 (50 iterations in 0.151s)
# [t-SNE] Iteration 7600: error = 1.2959720, gradient norm = 0.0002769 (50 iterations in 0.147s)
# [t-SNE] Iteration 7650: error = 1.2960310, gradient norm = 0.0001890 (50 iterations in 0.149s)
# [t-SNE] Iteration 7700: error = 1.2959359, gradient norm = 0.0002260 (50 iterations in 0.142s)
# [t-SNE] Iteration 7750: error = 1.2959733, gradient norm = 0.0001819 (50 iterations in 0.153s)
# [t-SNE] Iteration 7800: error = 1.2959222, gradient norm = 0.0001454 (50 iterations in 0.148s)
# [t-SNE] Iteration 7850: error = 1.2958584, gradient norm = 0.0002457 (50 iterations in 0.159s)
# [t-SNE] Iteration 7900: error = 1.2959083, gradient norm = 0.0001965 (50 iterations in 0.152s)
# [t-SNE] Iteration 7950: error = 1.2958486, gradient norm = 0.0002233 (50 iterations in 0.152s)
# [t-SNE] Iteration 8000: error = 1.2958843, gradient norm = 0.0002068 (50 iterations in 0.139s)
# [t-SNE] Iteration 8050: error = 1.2957952, gradient norm = 0.0002101 (50 iterations in 0.146s)
# [t-SNE] Iteration 8100: error = 1.2957656, gradient norm = 0.0002615 (50 iterations in 0.145s)
# [t-SNE] Iteration 8150: error = 1.2957540, gradient norm = 0.0001868 (50 iterations in 0.153s)
# [t-SNE] Iteration 8200: error = 1.2957978, gradient norm = 0.0001775 (50 iterations in 0.144s)
# [t-SNE] Iteration 8250: error = 1.2957866, gradient norm = 0.0001598 (50 iterations in 0.159s)
# [t-SNE] Iteration 8300: error = 1.2957574, gradient norm = 0.0001661 (50 iterations in 0.139s)
# [t-SNE] Iteration 8350: error = 1.2956369, gradient norm = 0.0002184 (50 iterations in 0.144s)
# [t-SNE] Iteration 8400: error = 1.2956830, gradient norm = 0.0002060 (50 iterations in 0.145s)
# [t-SNE] Iteration 8450: error = 1.2956486, gradient norm = 0.0001552 (50 iterations in 0.147s)
# [t-SNE] Iteration 8500: error = 1.2956386, gradient norm = 0.0002503 (50 iterations in 0.142s)
# [t-SNE] Iteration 8550: error = 1.2955709, gradient norm = 0.0002605 (50 iterations in 0.149s)
# [t-SNE] Iteration 8600: error = 1.2954907, gradient norm = 0.0003530 (50 iterations in 0.149s)
# [t-SNE] Iteration 8650: error = 1.2955701, gradient norm = 0.0003246 (50 iterations in 0.148s)
# [t-SNE] Iteration 8700: error = 1.2955642, gradient norm = 0.0002314 (50 iterations in 0.143s)
# [t-SNE] Iteration 8750: error = 1.2955400, gradient norm = 0.0002678 (50 iterations in 0.152s)
# [t-SNE] Iteration 8800: error = 1.2954794, gradient norm = 0.0002403 (50 iterations in 0.150s)
# [t-SNE] Iteration 8850: error = 1.2954664, gradient norm = 0.0002207 (50 iterations in 0.147s)
# [t-SNE] Iteration 8900: error = 1.2954152, gradient norm = 0.0001784 (50 iterations in 0.144s)
# [t-SNE] Iteration 8950: error = 1.2954155, gradient norm = 0.0001898 (50 iterations in 0.148s)
# [t-SNE] Iteration 9000: error = 1.2953416, gradient norm = 0.0007276 (50 iterations in 0.133s)
# [t-SNE] Iteration 9050: error = 1.2953483, gradient norm = 0.0004466 (50 iterations in 0.148s)
# [t-SNE] Iteration 9100: error = 1.2953762, gradient norm = 0.0002524 (50 iterations in 0.155s)
# [t-SNE] Iteration 9150: error = 1.2952974, gradient norm = 0.0002923 (50 iterations in 0.249s)
# [t-SNE] Iteration 9200: error = 1.2952476, gradient norm = 0.0002042 (50 iterations in 0.160s)
# [t-SNE] Iteration 9250: error = 1.2952642, gradient norm = 0.0002319 (50 iterations in 0.155s)
# [t-SNE] Iteration 9300: error = 1.2953055, gradient norm = 0.0001807 (50 iterations in 0.136s)
# [t-SNE] Iteration 9350: error = 1.2953011, gradient norm = 0.0001884 (50 iterations in 0.143s)
# [t-SNE] Iteration 9400: error = 1.2953072, gradient norm = 0.0004543 (50 iterations in 0.141s)
# [t-SNE] Iteration 9450: error = 1.2952700, gradient norm = 0.0001708 (50 iterations in 0.148s)
# [t-SNE] Iteration 9500: error = 1.2952518, gradient norm = 0.0002143 (50 iterations in 0.144s)
# [t-SNE] Iteration 9550: error = 1.2951993, gradient norm = 0.0002572 (50 iterations in 0.153s)
# [t-SNE] Iteration 9600: error = 1.2951437, gradient norm = 0.0003983 (50 iterations in 0.147s)
# [t-SNE] Iteration 9650: error = 1.2951494, gradient norm = 0.0002186 (50 iterations in 0.150s)
# [t-SNE] Iteration 9700: error = 1.2951642, gradient norm = 0.0002935 (50 iterations in 0.138s)
# [t-SNE] Iteration 9750: error = 1.2951596, gradient norm = 0.0002099 (50 iterations in 0.150s)
# [t-SNE] Iteration 9800: error = 1.2951548, gradient norm = 0.0003692 (50 iterations in 0.141s)
# [t-SNE] Iteration 9850: error = 1.2951050, gradient norm = 0.0003715 (50 iterations in 0.150s)
# [t-SNE] Iteration 9900: error = 1.2951280, gradient norm = 0.0001576 (50 iterations in 0.146s)
# [t-SNE] Iteration 9950: error = 1.2950773, gradient norm = 0.0002637 (50 iterations in 0.149s)
# [t-SNE] Iteration 10000: error = 1.2950828, gradient norm = 0.0002343 (50 iterations in 0.144s)
# [t-SNE] Iteration 10050: error = 1.2950803, gradient norm = 0.0002146 (50 iterations in 0.148s)
# [t-SNE] Iteration 10100: error = 1.2950522, gradient norm = 0.0002002 (50 iterations in 0.146s)
# [t-SNE] Iteration 10150: error = 1.2950559, gradient norm = 0.0002597 (50 iterations in 0.148s)
# [t-SNE] Iteration 10200: error = 1.2950387, gradient norm = 0.0001601 (50 iterations in 0.149s)
# [t-SNE] Iteration 10250: error = 1.2950606, gradient norm = 0.0002167 (50 iterations in 0.150s)
# [t-SNE] Iteration 10300: error = 1.2950277, gradient norm = 0.0001988 (50 iterations in 0.144s)
# [t-SNE] Iteration 10350: error = 1.2950180, gradient norm = 0.0001801 (50 iterations in 0.145s)
# [t-SNE] Iteration 10400: error = 1.2950107, gradient norm = 0.0001413 (50 iterations in 0.144s)
# [t-SNE] Iteration 10450: error = 1.2950351, gradient norm = 0.0002508 (50 iterations in 0.148s)
# [t-SNE] Iteration 10500: error = 1.2949777, gradient norm = 0.0001705 (50 iterations in 0.148s)
# [t-SNE] Iteration 10550: error = 1.2949789, gradient norm = 0.0001628 (50 iterations in 0.161s)
# [t-SNE] Iteration 10600: error = 1.2949446, gradient norm = 0.0006235 (50 iterations in 0.145s)
# [t-SNE] Iteration 10650: error = 1.2949755, gradient norm = 0.0002036 (50 iterations in 0.148s)
# [t-SNE] Iteration 10700: error = 1.2949756, gradient norm = 0.0002453 (50 iterations in 0.143s)
# [t-SNE] Iteration 10750: error = 1.2949715, gradient norm = 0.0002440 (50 iterations in 0.148s)
# [t-SNE] Iteration 10800: error = 1.2949349, gradient norm = 0.0002017 (50 iterations in 0.145s)
# [t-SNE] Iteration 10850: error = 1.2949498, gradient norm = 0.0001996 (50 iterations in 0.152s)
# [t-SNE] Iteration 10900: error = 1.2949346, gradient norm = 0.0002766 (50 iterations in 0.145s)
# [t-SNE] Iteration 10950: error = 1.2950097, gradient norm = 0.0001776 (50 iterations in 0.151s)
# [t-SNE] Iteration 11000: error = 1.2949847, gradient norm = 0.0002487 (50 iterations in 0.138s)
# [t-SNE] Iteration 11050: error = 1.2949389, gradient norm = 0.0001152 (50 iterations in 0.150s)
# [t-SNE] Iteration 11100: error = 1.2949340, gradient norm = 0.0005944 (50 iterations in 0.145s)
# [t-SNE] Iteration 11150: error = 1.2949108, gradient norm = 0.0003085 (50 iterations in 0.148s)
# [t-SNE] Iteration 11200: error = 1.2948985, gradient norm = 0.0001220 (50 iterations in 0.145s)
# [t-SNE] Iteration 11250: error = 1.2948298, gradient norm = 0.0003021 (50 iterations in 0.154s)
# [t-SNE] Iteration 11300: error = 1.2948495, gradient norm = 0.0002419 (50 iterations in 0.146s)
# [t-SNE] Iteration 11350: error = 1.2948475, gradient norm = 0.0001374 (50 iterations in 0.144s)
# [t-SNE] Iteration 11400: error = 1.2948742, gradient norm = 0.0001485 (50 iterations in 0.143s)
# [t-SNE] Iteration 11450: error = 1.2948222, gradient norm = 0.0002052 (50 iterations in 0.149s)
# [t-SNE] Iteration 11500: error = 1.2948222, gradient norm = 0.0001439 (50 iterations in 0.141s)
# [t-SNE] Iteration 11550: error = 1.2948327, gradient norm = 0.0001920 (50 iterations in 0.155s)
# [t-SNE] Iteration 11600: error = 1.2948153, gradient norm = 0.0002906 (50 iterations in 0.149s)
# [t-SNE] Iteration 11650: error = 1.2948244, gradient norm = 0.0003117 (50 iterations in 0.147s)
# [t-SNE] Iteration 11700: error = 1.2947968, gradient norm = 0.0001123 (50 iterations in 0.142s)
# [t-SNE] Iteration 11750: error = 1.2948062, gradient norm = 0.0001628 (50 iterations in 0.149s)
# [t-SNE] Iteration 11800: error = 1.2948050, gradient norm = 0.0001350 (50 iterations in 0.201s)
# [t-SNE] Iteration 11850: error = 1.2947724, gradient norm = 0.0002072 (50 iterations in 0.150s)
# [t-SNE] Iteration 11900: error = 1.2947917, gradient norm = 0.0001122 (50 iterations in 0.193s)
# [t-SNE] Iteration 11950: error = 1.2947785, gradient norm = 0.0001396 (50 iterations in 0.184s)
# [t-SNE] Iteration 12000: error = 1.2947683, gradient norm = 0.0001819 (50 iterations in 0.147s)
# [t-SNE] Iteration 12050: error = 1.2947049, gradient norm = 0.0004558 (50 iterations in 0.148s)
# [t-SNE] Iteration 12100: error = 1.2947593, gradient norm = 0.0001009 (50 iterations in 0.151s)
# [t-SNE] Iteration 12150: error = 1.2947685, gradient norm = 0.0001194 (50 iterations in 0.222s)
# [t-SNE] Iteration 12200: error = 1.2947323, gradient norm = 0.0001560 (50 iterations in 0.147s)
# [t-SNE] Iteration 12250: error = 1.2946990, gradient norm = 0.0002621 (50 iterations in 0.145s)
# [t-SNE] Iteration 12300: error = 1.2947044, gradient norm = 0.0001030 (50 iterations in 0.139s)
# [t-SNE] Iteration 12350: error = 1.2946897, gradient norm = 0.0002117 (50 iterations in 0.149s)
# [t-SNE] Iteration 12400: error = 1.2947309, gradient norm = 0.0002083 (50 iterations in 0.146s)
# [t-SNE] Iteration 12450: error = 1.2946588, gradient norm = 0.0002807 (50 iterations in 0.154s)
# [t-SNE] Iteration 12500: error = 1.2946827, gradient norm = 0.0001618 (50 iterations in 0.145s)
# [t-SNE] Iteration 12550: error = 1.2946402, gradient norm = 0.0002094 (50 iterations in 0.175s)
# [t-SNE] Iteration 12600: error = 1.2946146, gradient norm = 0.0002762 (50 iterations in 0.155s)
# [t-SNE] Iteration 12650: error = 1.2946585, gradient norm = 0.0001544 (50 iterations in 0.145s)
# [t-SNE] Iteration 12700: error = 1.2946243, gradient norm = 0.0001166 (50 iterations in 0.143s)
# [t-SNE] Iteration 12750: error = 1.2946470, gradient norm = 0.0001522 (50 iterations in 0.159s)
# [t-SNE] Iteration 12800: error = 1.2946603, gradient norm = 0.0002608 (50 iterations in 0.148s)
# [t-SNE] Iteration 12850: error = 1.2946203, gradient norm = 0.0002245 (50 iterations in 0.155s)
# [t-SNE] Iteration 12900: error = 1.2946005, gradient norm = 0.0001473 (50 iterations in 0.146s)
# [t-SNE] Iteration 12950: error = 1.2946010, gradient norm = 0.0001816 (50 iterations in 0.145s)
# [t-SNE] Iteration 13000: error = 1.2946097, gradient norm = 0.0002133 (50 iterations in 0.146s)
# [t-SNE] Iteration 13050: error = 1.2946240, gradient norm = 0.0001136 (50 iterations in 0.147s)
# [t-SNE] Iteration 13100: error = 1.2946080, gradient norm = 0.0001270 (50 iterations in 0.148s)
# [t-SNE] Iteration 13150: error = 1.2945994, gradient norm = 0.0002183 (50 iterations in 0.154s)
# [t-SNE] Iteration 13200: error = 1.2945477, gradient norm = 0.0001959 (50 iterations in 0.147s)
# [t-SNE] Iteration 13250: error = 1.2945422, gradient norm = 0.0002327 (50 iterations in 0.149s)
# [t-SNE] Iteration 13300: error = 1.2945472, gradient norm = 0.0001847 (50 iterations in 0.139s)
# [t-SNE] Iteration 13350: error = 1.2945561, gradient norm = 0.0002074 (50 iterations in 0.143s)
# [t-SNE] Iteration 13400: error = 1.2945597, gradient norm = 0.0004298 (50 iterations in 0.141s)
# [t-SNE] Iteration 13450: error = 1.2945400, gradient norm = 0.0002655 (50 iterations in 0.155s)
# [t-SNE] Iteration 13500: error = 1.2945237, gradient norm = 0.0002828 (50 iterations in 0.146s)
# [t-SNE] Iteration 13550: error = 1.2945222, gradient norm = 0.0002186 (50 iterations in 0.153s)
# [t-SNE] Iteration 13600: error = 1.2944882, gradient norm = 0.0009265 (50 iterations in 0.138s)
# [t-SNE] Iteration 13650: error = 1.2945482, gradient norm = 0.0002363 (50 iterations in 0.144s)
# [t-SNE] Iteration 13700: error = 1.2944747, gradient norm = 0.0001671 (50 iterations in 0.140s)
# [t-SNE] Iteration 13750: error = 1.2944345, gradient norm = 0.0002400 (50 iterations in 0.146s)
# [t-SNE] Iteration 13800: error = 1.2944185, gradient norm = 0.0002417 (50 iterations in 0.146s)
# [t-SNE] Iteration 13850: error = 1.2943918, gradient norm = 0.0001954 (50 iterations in 0.143s)
# [t-SNE] Iteration 13900: error = 1.2943213, gradient norm = 0.0002016 (50 iterations in 0.143s)
# [t-SNE] Iteration 13950: error = 1.2942806, gradient norm = 0.0001956 (50 iterations in 0.147s)
# [t-SNE] Iteration 14000: error = 1.2942899, gradient norm = 0.0002440 (50 iterations in 0.137s)
# [t-SNE] Iteration 14050: error = 1.2943811, gradient norm = 0.0003522 (50 iterations in 0.150s)
# [t-SNE] Iteration 14100: error = 1.2943518, gradient norm = 0.0002297 (50 iterations in 0.144s)
# [t-SNE] Iteration 14150: error = 1.2943546, gradient norm = 0.0001828 (50 iterations in 0.148s)
# [t-SNE] Iteration 14200: error = 1.2943404, gradient norm = 0.0001699 (50 iterations in 0.143s)
# [t-SNE] Iteration 14250: error = 1.2943584, gradient norm = 0.0002003 (50 iterations in 0.152s)
# [t-SNE] Iteration 14300: error = 1.2944139, gradient norm = 0.0008287 (50 iterations in 0.137s)
# [t-SNE] Iteration 14300: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 14300 iterations: 1.294414

# %%
fig, ax = plt.subplots(1, figsize=(6, 5), dpi=100)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
duration = np.log10(df_clean['T90_end'] - df_clean['T90_start'])
duration = duration.iloc[mask_fft]

sc = ax.scatter(y_tsne[:, 0], y_tsne[:, 1], s=2.0, c=duration, cmap='plasma')
cbar = plt.colorbar(sc)
cbar.ax.set_ylabel('Duration', rotation=270, labelpad=10)
plt.show()

# %% [markdown]
# And again, repeat with `UMAP`:

# %%
map = umap.UMAP(n_components=2, n_neighbors=20, min_dist=0.1, 
                random_state=42, set_op_mix_ratio=0.25)
y_umap = map.fit_transform(X_data_mod)

# %%
fig, ax = plt.subplots(1, figsize=(6, 5), dpi=100)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
duration = np.log10(df_clean['T90_end'] - df_clean['T90_start'])
duration = duration.iloc[mask_fft]

sc = ax.scatter(y_umap[:, 0], y_umap[:, 1], s=2.0, c=duration, cmap='plasma')
cbar = plt.colorbar(sc)
cbar.ax.set_ylabel('Duration', rotation=270, labelpad=10)
plt.show()

# %% [markdown]
# Hey! After applying our transformation of the inputs, the resulting embeddings hint at the fact that we indeed have two almost distinct classes (with some intersection probably). When coloured by time `duration`, this suggests that the two classes have either short or long duration. That's very useful!

# %% [markdown]
# 5. Try experimenting: the main parameter in `t-SNE` is `perplexity` - try using the values of `5, 10, 15, 20, 50`. The analogous parameter for `UMAP` is `n_neighbours`. Can you find a number that makes an optimal separation of bursts? How would this number have to change depending on the size of the dataset, eg. if you have **10x**, **100x** more samples?
#
#     * Probably `perplexity=10-20` makes a good separation. To preserve the same structure in a dataset that has more samples, one would have to increase `perplexity`, as more data would fill the available space. Therefore, as a rule of thumb, one can take usually start with a `perplexity` of $\sqrt{n}$ for $n$ samples in the data (as a first guess).
#
# 6. Try changing the different options `method='exact'` $\left[ \mathcal{O}(n^2) \right]$ and `method='barnes_hut'` $\left[ \mathcal{O}(n \log{n}) \right]$. The complexity of the operations with the two is different: `barnes_hut` provides an approximate map, but with less time spent.
#
# 7. Try different value of the number of iterations (`n_iter`). Can you reach the point where the algorithm converges (be gentle to your computer)? Remember that you need to have at least `n_iter = 250`, as the algorithm requires those for calibration. If it takes too long to converge try taking a smaller sub-sample.
#
#     * Setting `n_iters=15000`, gives enough time to converge on a solution. If it takes too long to converge, you can try to reduce the dimensionality of the data given to `t-SNE` or `UMAP` using `PCA`. `t-SNE` is the slowest of the two.

# %% [markdown]
# Ok, ones we have managed to obtain a useful embedding, how can we used it?
#
# First, we can assign labels to different clusters. Clustering can be done with a range of available algorithms. For comparison, see: \
# https://scikit-learn.org/stable/modules/clustering.html.
#
# Try using various options, like `k-Means` (will likely not succeed here, as the two clusters are not balanced). Here, we will use `DBSCAN`. It will assign all separate clusters a unique non-negative integer label (eg., $i=0,1,2,...$), while the noisy samples, if present, will be labelled as $i=-1$. Reference: [DBSCAN](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html#sklearn.cluster.DBSCAN).

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=6.5, min_samples=15)
y_labels = dbscan.fit_predict(y_tsne)
print(f"unique class labels: {np.unique(y_labels)}")
# Out:
# unique class labels: [0 1]

# %% [markdown]
# To get the above clean clustering, one would have to balance the two parameters: `eps` & `min_samples`. The first defines the distance scale of the neighbourhood, while the second - the membership (number of neighbours). Combinations of the two can make `DBSCAN` sensitive to clusters on different scales.
#
# After getting the clustering and assigning the labels to the red and blue clusters, we can investigate one of the properties for the both clusters (`duration`):

# %%
fig, ax = plt.subplots(1, figsize=(5, 5), dpi=100)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
duration = np.log10(df_clean['T90_end'] - df_clean['T90_start'])
duration = duration.iloc[mask_fft]

a, b = np.unique(y_labels)
db0 = y_labels == a
db1 = y_labels == b
sc = ax.scatter(y_tsne[db0, 0], y_tsne[db0, 1], s=2.0, c='b', alpha=0.5)
sc = ax.scatter(y_tsne[db1, 0], y_tsne[db1, 1], s=2.0, c='r', alpha=0.5)
cbar.ax.set_ylabel('Duration', rotation=270, labelpad=10)
plt.show()

# %%
# bin two distributions of durations (defined by the above red-blue clusters)
bins = np.arange(-1, 3.0, 0.1) # duration bins
h0, x0 = np.histogram(duration[db0], bins=bins) # bin durations
h1, x1 = np.histogram(duration[db1], bins=bins)
h_tot, x_tot = np.histogram(duration, bins=bins)
x1mid = (x1[1:] + x1[:-1]) * 0.5 # get central poisitions of bins using the bin edges
x0mid = (x0[1:] + x0[:-1]) * 0.5
xtotmid = (x_tot[1:] + x_tot[:-1]) * 0.5

fig, ax = plt.subplots(1, subplot_kw={'xlabel': 'log(Duration)', 
                                      'ylabel': "Number"}, 
                       dpi=100) # plot the distributions
ax.bar(x1mid, h1, width=0.1, color='b', alpha=0.4, label='short bursts')
ax.bar(x0mid, h0, width=0.1, color='r', alpha=0.4, label='long bursts')
ax.bar(xtotmid, h_tot, width=0.1, color='w', alpha=0.3, edgecolor='k')
plt.legend()
plt.show()

# %% [markdown]
# There is a nice separation that confirms that the two classes have different distributions in `duration`. However, you can see that there are a few "short" outliers far inside the "long" distribution (i.e. the blue among the red at $1.5 < log(duration) < 2.0$). These could potentially be physically anomolous detections (i.e. something wrong with their raw data, maybe instrument effects or some biased preprocessing was actually done on those data).
#
# To summarise, what we have done above is
#
# * We introduced a novel way of classifying objects that were previously not known to form distinct classes.
#
# * We used one of the physical properties of the objects to do that: `duration`.
#
# * This is a clear example of using dimension reduction in an **unsupervised** way.
#
# * Can you formulate the classes using other properties of the space bursts?
#
# * If you are convinced that the classification is accurate, you could use this method to label the data and use it as a training set in a **supervised** setting. This means you could use these training features and labels to make predictions on new data in the future.
#
# Isn't it great? 😊
#
# As a bonus, the plot below shows an example of how you could classify new objects in the embedding where we have just labelled the objects. Here the new objects will be just a meshgrid sampling the full embedding space:

# %%
from sklearn.svm import SVC

# as one option among many, we could use a support vector machine (SVM)
# to split the embedding into sub-spaces for classification
# first, create a meshgrid of the parameter space 
# (in the coordinates of the t-SNE embedding)
xs = np.arange(y_tsne[:, 0].min(), y_tsne[:, 0].max()+1, 1)
ys = np.arange(y_tsne[:, 1].min(), y_tsne[:, 1].max()+1, 1)
xx, yy = np.meshgrid(xs, ys)
xy = np.concatenate((xx.reshape(-1, 1), yy.reshape(-1, 1)), axis=1) # reshape from mesh into a [nsamples, 2] input for a classifier
n = len(xs) # number of points on a mesh side

# train an SVM and predict on a meshgrid
svc = SVC(kernel='poly', probability=True)
svc.fit(y_tsne, y_labels)
y_mesh = svc.predict_proba(xy)
y_mesh = y_mesh.reshape(-1, n, 2) # reshape into a mesh again

# %% [markdown]
# After traing the SVM using our labelled training data, we can see how it would classify new objects within this whole 2D space. Note that the decision boundary here is **arbitrary** and depends on the kernel you choose, other classifier parameters and the training data (i.e. red and blue points). So keep that in mind and be careful.

# %%
fig, ax = plt.subplots(1, figsize=(5, 5), dpi=100)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
duration = np.log10(df_clean['T90_end'] - df_clean['T90_start'])
duration = duration.iloc[mask_fft]

a, b = np.unique(y_labels)
db0 = y_labels == a
db1 = y_labels == b
ax.contourf(xx, yy, y_mesh[:, :, 0], levels=np.arange(0,1.1,0.1), cmap='RdBu', alpha=0.2)
sc = ax.scatter(y_tsne[db0, 0], y_tsne[db0, 1], s=2.0, c='b', alpha=0.5)
sc = ax.scatter(y_tsne[db1, 0], y_tsne[db1, 1], s=2.0, c='r', alpha=0.5)
cbar.ax.set_ylabel('Duration', rotation=270, labelpad=10)
plt.show()

# %% [markdown]
# ## Dataset 2. Back to COSMOS2015 (galaxies)

# %% [markdown]
# Now, repeat the experiment from the previous session with the galaxies dataset. This time think about preprocessing and hyperparameter optimisation and repeat the exercise. At the end try to classify galaxies as either `alive` or `dead`.
#
# 1. Recall that the linear `PCA` before was not capable of linearly separating two types of galaxies at all. In fact, the data you were given were not entirely ready. You need to preprocess them first. For this, take all fluxes and normalize them by one of the other fluxes. $^{1,2}$ Repeat the exercise. Do you get better separation?
#
# $^1$ Hint: it turns out the star forming and dead galaxies are most different in the bluer bands (like `u_flux`).\
# $^2$ Hint: plot distributions of features before preprocessing and compare with the same after.

# %%
# turn off warnings, no one needs them...
pd.options.mode.chained_assignment = None  # default='warn'

file = "datasets/cosmos2015.csv"
df = pd.read_csv(file, index_col=False)

# select a random sub-sample of the dataset
n = 10000
idxs = np.arange(df.shape[0])
idxs_rand = np.random.choice(idxs, size=n)
df_cut = df.iloc[idxs_rand] # dataframe
X = df.iloc[idxs_rand].values # array

flux_cols = list(df.columns[4:]) # flux column names
flux_idxs = np.argwhere(np.isin(df.columns, flux_cols)).flatten() # flux column indices

# %% [markdown]
# Plot feature distributions before their normalization:

# %%
fig, ax = plt.subplots(1, subplot_kw={'xlabel': "Feature range", 
                                      'ylabel': "Frequency"}, 
                       dpi=100)
for i, col in enumerate(flux_cols):
    vec = X[:, flux_idxs[i]]
    vec = vec[(vec > (-10)) & (vec < 60)]
    ax.hist(vec, bins=100, label=col, density=True, histtype='step')
ax.set_ylim(0, 0.1)
plt.legend()
plt.show()

# %% [markdown]
# Normalize the data:

# %%
# normalize fluxes 
norm_flux = df_cut.loc[:, 'u_flux'].values
X_trans = np.copy(X)
for col in flux_idxs:
    X_trans[:, col] = X_trans[:, col] / norm_flux

# %% [markdown]
# The result of the normalization is below. The distributions are a little more closely spaced and span the similar numerical ranges.
#
# You can experiment here and investigate other ways of transforming these feature distributions. For reference, see: https://scikit-learn.org/stable/modules/preprocessing.html.

# %%
fig, ax = plt.subplots(1, subplot_kw={'xlabel': "Feature range", 
                                      'ylabel': "Frequency"}, 
                       dpi=100)
for i, col in enumerate(flux_cols):
    vec = X_trans[:, flux_idxs[i]]
    vec = vec[(vec > (-10)) & (vec < 60)]
    ax.hist(vec, bins=100, label=col, density=True, histtype='step')
ax.set_ylim(0, 0.1)
plt.legend()
plt.show()

# %% [markdown]
# We can try `PCA` again (this time on the preprocessed data):

# %%
pca = PCA(n_components=2, svd_solver='full')
y_pcs = pca.fit_transform(X_trans[:, flux_idxs]) # train only on fluxes (raw observed data)

# %%
fig, ax = plt.subplots(1, figsize=(5, 5), dpi=100)
ax.set_xlim(np.percentile(y_pcs[:,0], 99), np.percentile(y_pcs[:,0], 1))
ax.set_ylim(np.percentile(y_pcs[:,1], 99), np.percentile(y_pcs[:,1], 1))
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
is_sf = np.isin(df_cut.loc[:, 'is_star_forming'], 1)

ax.scatter(y_pcs[is_sf, 0], y_pcs[is_sf, 1], s=0.02, c='b')
ax.scatter(y_pcs[~is_sf, 0], y_pcs[~is_sf, 1], s=0.02, c='r')
ax.annotate("star forming", xy=(0.05, 0.9), xycoords="axes fraction", 
            color='b', fontsize=12)
ax.annotate("dead", xy=(0.05, 0.86), xycoords="axes fraction", 
            color='r', fontsize=12)
plt.show()

# %% [markdown]
# The above is somewhat better than a mixed blob we obtained in the previous session.

# %% [markdown]
# ### t-SNE

# %%
tsne = TSNE(n_components=2, init='random', method='barnes_hut', 
            random_state=42, perplexity=15, max_iter=500, verbose=2)
y_tsne = tsne.fit_transform(X_trans[:, flux_idxs])
# Out:
# [t-SNE] Computing 46 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.008s...
# [t-SNE] Computed neighbors for 10000 samples in 0.164s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.840270
# [t-SNE] Computed conditional probabilities in 0.108s
# [t-SNE] Iteration 50: error = 104.5449677, gradient norm = 0.0503305 (50 iterations in 1.522s)
# [t-SNE] Iteration 100: error = 85.4030838, gradient norm = 0.0150362 (50 iterations in 1.355s)
# [t-SNE] Iteration 150: error = 80.5361328, gradient norm = 0.0100421 (50 iterations in 1.204s)
# [t-SNE] Iteration 200: error = 77.9784393, gradient norm = 0.0078674 (50 iterations in 1.206s)
# [t-SNE] Iteration 250: error = 76.4056549, gradient norm = 0.0052818 (50 iterations in 1.283s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 76.405655
# [t-SNE] Iteration 300: error = 2.8589129, gradient norm = 0.0139156 (50 iterations in 1.271s)
# [t-SNE] Iteration 350: error = 2.1556945, gradient norm = 0.0136158 (50 iterations in 1.209s)
# [t-SNE] Iteration 400: error = 1.7838879, gradient norm = 0.0126173 (50 iterations in 1.281s)
# [t-SNE] Iteration 450: error = 1.5559990, gradient norm = 0.0117440 (50 iterations in 1.231s)
# [t-SNE] Iteration 500: error = 1.4018998, gradient norm = 0.0110314 (50 iterations in 1.217s)
# [t-SNE] KL divergence after 500 iterations: 1.401900

# %%
fig, ax = plt.subplots(1, figsize=(5, 5), dpi=100)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
is_sf = np.isin(df_cut.loc[:, 'is_star_forming'], 1)

ax.scatter(y_tsne[is_sf, 0], y_tsne[is_sf, 1], s=0.05, c='b')
ax.scatter(y_tsne[~is_sf, 0], y_tsne[~is_sf, 1], s=0.05, c='r')
ax.annotate("star forming", xy=(0.05, 0.9), xycoords="axes fraction", 
            color='b', fontsize=12)
ax.annotate("dead", xy=(0.05, 0.86), xycoords="axes fraction", 
            color='r', fontsize=12)
plt.show()

# %% [markdown]
# ### UMAP

# %%
map = umap.UMAP(n_components=2, n_neighbors=50, random_state=42)
y_umap = map.fit_transform(X_trans[:, flux_idxs])

# %%
fig, ax = plt.subplots(1, figsize=(5, 5), dpi=100)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
is_sf = np.isin(df_cut.loc[:, 'is_star_forming'], 1)

ax.scatter(y_umap[is_sf, 0], y_umap[is_sf, 1], s=0.05, c='b')
ax.scatter(y_umap[~is_sf, 0], y_umap[~is_sf, 1], s=0.05, c='r')
ax.annotate("star forming", xy=(0.05, 0.9), xycoords="axes fraction", 
            color='b', fontsize=12)
ax.annotate("dead", xy=(0.05, 0.86), xycoords="axes fraction", 
            color='r', fontsize=12)
plt.show()

# %% [markdown]
# 2. Even with a high degree of separation, whether star forming or dead, there is a continuum of galaxies with varying masses and rates of star formation. Therefore, do you ever expect there to be discrete islands of galaxies when you reduce the dimensions? $^1$
#
#     * we can attempt to reduce the data to receive those islands. But, likely, for this we have to remove a bias in these data: `redshift`. The issue here is similar to the gamma-ray burst dataset (the spectra are not aligned in the wavelength axis and therefore, as there is a distribution of redshifts, the spectra will always form some sort of continuum).
#
# $^1$ Hint: produce scatter plots in the reduced space and colour the points by different galaxy properties.

# %% [markdown]
# We have just tried using clustering with the above dataset. How well did the dimension reduction manage to split the data into separate meaningful clusters? Visually, there is a meaningfull separation, but no separate clusters. If we didn't have the labels, the embeddings above would not be useful (eg., imaging that all points above are all black - you wouldn't be able to see different clusters). But here we can show an example of how we can cheat when we do have the labels (i.e. in a **supervised** task). The examples of how we can score the performance in such tasks are presented below:
#
# **Example 1. Let the neighbours vote.**

# %%
def get_prob(ycoords, ylabels, radius=1):
    """
    This function gives a probability for an object to be 
    an 'active' galaxy or 'dead'. It takes an object, 
    locates all its neighbours withing a specified radius
    and calculates the probability as the fraction: 
        prob = N_active / (N_active + N_dead)
    
    Parameters: 
    ----------
    ycoords - coordinates in an embedding y: [component1, component2].
    ylabels - labels of the objects: 1 - galaxy is alive, 0 - dead.
    radius - to define neighbours around every point.
    """
    probs = np.empty(shape=(len(ycoords))) # to store probabilities
    for i, dot in enumerate(ycoords):
        # check which points are in the neighbourhood of the current point
        dist = np.sqrt( (ycoords[:, 0] - dot[0])**2 + (ycoords[:, 1] - dot[1])**2 )
        is_in_circle = dist < radius
        
        # within the circle divide the number of living galaxies 
        # by the number of dead galaxies to calculate the probability
        # of being a living galaxy
        prob = ylabels[is_in_circle].sum() / len(ylabels[is_in_circle])
        probs[i] = prob
    return probs

ylabels = is_sf.astype(int) # labels: 1 - galaxy is alive, 0 - dead.

# t-SNE probabilities
prob_alive_tsne = get_prob(y_tsne, ylabels, radius=5)

# UMAP probabilities
prob_alive_umap = get_prob(y_umap, ylabels, radius=3)

# %% [markdown]
# The distribution of the probabilities looks like:

# %%
fig, ax = plt.subplots(1, subplot_kw={'xlabel': "Probability (alive)", 
                                      'ylabel': "Number"}, 
                       dpi=100)
ax.hist(prob_alive_tsne, bins=100)
ax.set_title('t-SNE')
plt.show()

# %% [markdown]
# ... and for `UMAP`:

# %%
fig, ax = plt.subplots(1, subplot_kw={'xlabel': "Probability (alive)", 
                                      'ylabel': "Number"}, 
                       dpi=100)
ax.hist(prob_alive_umap, bins=100)
ax.set_title('UMAP')
plt.show()

# %% [markdown]
# We can also colour our embedding by the object probabilities:

# %%
fig, ax = plt.subplots(1, figsize=(6, 5), dpi=100)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')

sc = ax.scatter(y_tsne[:, 0], y_tsne[:, 1], s=0.05, c=prob_alive_tsne, cmap='jet_r')
cbar = plt.colorbar(sc)
cbar.set_label(label='Probability (alive)', rotation=270, labelpad=12)
cbar.set_ticks(np.arange(0, 1.1, 0.2))
plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(6, 5), dpi=100)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')

sc = ax.scatter(y_umap[:, 0], y_umap[:, 1], s=0.05, c=prob_alive_umap, cmap='jet_r')
cbar = plt.colorbar(sc)
cbar.set_label(label='Probability (alive)', rotation=270, labelpad=12)
cbar.set_ticks(np.arange(0, 1.1, 0.2))
plt.show()

# %% [markdown]
# We can also plot the **ROC curves** based on the above classification:

# %%
from sklearn.metrics import roc_curve

fpr_tsne, tpr_tsne, _ = roc_curve(ylabels, prob_alive_tsne)
fpr_umap, tpr_umap, _ = roc_curve(ylabels, prob_alive_umap)

fig, ax = plt.subplots(1, subplot_kw={'xlabel': "FPR", 
                                      'ylabel': "TPR"}, 
                       dpi=100)
ax.plot(fpr_tsne, tpr_tsne, label='t-SNE')
ax.plot(fpr_umap, tpr_umap, label='UMAP')
plt.legend()
plt.show()

# %% [markdown]
# ## PCA + t-SNE
#
# 4. Try experimenting: can you combine `PCA` (or `kPCA`) and `t-SNE` as part of the preprocessing and training procedures? Note, this is not guaranteed to give better results, but could be worth exploring.

# %%
# preprocessing
kpca = KernelPCA(n_components=6, kernel='poly')
y_pcs = kpca.fit_transform(X_trans[:, flux_idxs])

# %%
# reducing dimensions to 2 components
map = TSNE(n_components=2, perplexity=15, max_iter=1000, 
           random_state=42, verbose=2)
y_comb = map.fit_transform(y_pcs)
# Out:
# [t-SNE] Computing 46 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.012s...
# [t-SNE] Computed neighbors for 10000 samples in 0.159s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 2.458402
# [t-SNE] Computed conditional probabilities in 0.208s
# [t-SNE] Iteration 50: error = 96.2839584, gradient norm = 0.0295545 (50 iterations in 2.486s)
# [t-SNE] Iteration 100: error = 81.8716354, gradient norm = 0.0139858 (50 iterations in 1.766s)
# [t-SNE] Iteration 150: error = 77.4022980, gradient norm = 0.0086817 (50 iterations in 1.635s)
# [t-SNE] Iteration 200: error = 75.1161804, gradient norm = 0.0060824 (50 iterations in 1.305s)
# [t-SNE] Iteration 250: error = 73.7078171, gradient norm = 0.0047352 (50 iterations in 1.568s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.707817
# [t-SNE] Iteration 300: error = 2.7673733, gradient norm = 0.0134364 (50 iterations in 1.423s)
# [t-SNE] Iteration 350: error = 2.0791988, gradient norm = 0.0137076 (50 iterations in 1.239s)
# [t-SNE] Iteration 400: error = 1.6971465, gradient norm = 0.0128213 (50 iterations in 1.372s)
# [t-SNE] Iteration 450: error = 1.4615173, gradient norm = 0.0118898 (50 iterations in 1.225s)
# [t-SNE] Iteration 500: error = 1.3030132, gradient norm = 0.0111442 (50 iterations in 1.321s)
# [t-SNE] Iteration 550: error = 1.1890800, gradient norm = 0.0104521 (50 iterations in 1.263s)
# [t-SNE] Iteration 600: error = 1.1043932, gradient norm = 0.0097262 (50 iterations in 1.434s)
# [t-SNE] Iteration 650: error = 1.0403328, gradient norm = 0.0089688 (50 iterations in 1.211s)
# [t-SNE] Iteration 700: error = 0.9903049, gradient norm = 0.0082720 (50 iterations in 1.361s)
# [t-SNE] Iteration 750: error = 0.9502971, gradient norm = 0.0076946 (50 iterations in 1.294s)
# [t-SNE] Iteration 800: error = 0.9176729, gradient norm = 0.0071292 (50 iterations in 1.626s)
# [t-SNE] Iteration 850: error = 0.8911505, gradient norm = 0.0064116 (50 iterations in 1.197s)
# [t-SNE] Iteration 900: error = 0.8694781, gradient norm = 0.0059146 (50 iterations in 1.367s)
# [t-SNE] Iteration 950: error = 0.8509984, gradient norm = 0.0054576 (50 iterations in 1.171s)
# [t-SNE] Iteration 1000: error = 0.8358540, gradient norm = 0.0048438 (50 iterations in 1.457s)
# [t-SNE] KL divergence after 1000 iterations: 0.835854

# %%
fig, ax = plt.subplots(1, figsize=(5, 5), dpi=100)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
is_sf = np.isin(df_cut.loc[:, 'is_star_forming'], 1)

ax.scatter(y_comb[is_sf, 0], y_comb[is_sf, 1], s=0.05, c='b')
ax.scatter(y_comb[~is_sf, 0], y_comb[~is_sf, 1], s=0.05, c='r')
ax.annotate("star forming", xy=(0.05, 0.9), xycoords="axes fraction", 
            color='b', fontsize=12)
ax.annotate("dead", xy=(0.05, 0.86), xycoords="axes fraction", 
            color='r', fontsize=12)
plt.show()
